# %% [markdown]
# # ASSIGNMENT 1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy.sparse import csr_matrix

# %%
# Load csv file into pandas Data Frame
df=pd.read_csv("Dataset.csv")

# %%
df
# Out:
#       3.9493650708789314   472.32717269379486
# 0               3.584879           457.941274
# 1               4.573572           488.837460
# 2               4.976158           445.824528
# 3               5.068445           504.324621
# 4               6.189291           432.791486
# ...                  ...                  ...
# 1452         1000.587581           516.127116
# 1453          998.476258           504.703988
# 1454         1000.239569           546.959005
# 1455         1000.364005           537.235243
# 1456         1000.381256           529.340079
#
# [1457 rows x 2 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df.columns=['X','Y']

# %%
sns.scatterplot(data=df,x='X',y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df.describe()
# Out:
#                  X            Y
# count  1457.000000  1457.000000
# mean    499.862842   407.617903
# std     233.272858   258.465551
# min       3.584879     0.449527
# 25%     352.534483   220.166769
# 50%     504.149710   324.472290
# 75%     630.715330   581.614602
# max    1000.587581   997.192820

# %%
df.head(50)
# Out:
#             X           Y
# 0    3.584879  457.941274
# 1    4.573572  488.837460
# 2    4.976158  445.824528
# 3    5.068445  504.324621
# 4    6.189291  432.791486
# 5    5.675933  423.663611
# 6    6.055211  515.874518
# 7    7.350473  414.658990
# 8    8.308251  405.286448
# 9    7.469530  528.274077
# 10  10.344400  395.164413
# 11   9.331883  541.195225
# 12  11.072704  385.677116
# 13  10.845623  552.410262
# 14  13.110266  375.444583
# 15  12.397154  562.111152
# 16  12.331174  471.874942
# 17  12.314390  457.781532
# 18  14.902837  366.309932
# 19  12.885811  494.004964
# 20  11.429514  483.280979
# 21  13.382508  444.463191
# 22  14.431324  427.976728
# 23  14.921794  572.033351
# 24  14.390165  512.447132
# 25  17.538176  356.789854
# 26  15.752084  414.661414
# 27  17.093225  404.430032
# 28  15.947985  529.255860
# 29  17.299109  583.299608
# 30  20.107382  347.401422
# 31  19.471172  389.562366
# 32  18.096440  542.817518
# 33  19.663280  594.345899
# 34  22.647028  335.879202
# 35  20.785949  559.617660
# 36  19.515008  549.814360
# 37  22.754193  374.069953
# 38  24.235081  362.838157
# 39  22.780031  605.663171
# 40  26.308632  324.472290
# 41  24.061436  574.275029
# 42  26.021622  616.578106
# 43  28.365700  349.228195
# 44  29.860141  314.287038
# 45  26.185045  585.101785
# 46  29.051051  596.244126
# 47  32.182941  334.645610
# 48  29.260587  627.113687
# 49  33.290961  303.984882

# %%
df.tail(50)
# Out:
#             X       Y
# 1406   976.55  396.79
# 1407   973.03  690.60
# 1408   978.86  407.64
# 1409   976.65  650.92
# 1410   981.03  418.76
# 1411   976.76  679.74
# 1412   979.08  670.39
# 1413   978.79  638.05
# 1414   981.22  381.47
# 1415   983.22  429.68
# 1416   981.65  627.29
# 1417   982.64  660.18
# 1418   983.26  616.01
# 1419   985.92  442.26
# 1420   984.72  395.54
# 1421   987.05  453.72
# 1422   987.07  406.49
# 1423   984.92  649.43
# 1424   986.19  604.87
# 1425   987.00  594.39
# 1426   988.72  465.18
# 1427   988.68  585.31
# 1428   990.23  477.88
# 1429   990.17  419.45
# 1430   987.67  638.54
# 1431   989.41  574.71
# 1432   990.30  562.63
# 1433   991.46  496.40
# 1434   992.23  485.26
# 1435   992.25  431.78
# 1436   991.71  549.27
# 1437   991.95  511.37
# 1438   992.56  535.71
# 1439   992.58  523.24
# 1440   990.84  626.55
# 1441   992.05  615.99
# 1442   994.29  444.30
# 1443   994.04  605.81
# 1444   995.87  456.49
# 1445   997.92  468.63
# 1446   996.40  594.28
# 1447   996.85  582.99
# 1448   998.48  570.97
# 1449   998.58  480.33
# 1450   999.19  557.98
# 1451   999.94  493.89
# 1452  1000.59  516.13
# 1454  1000.24  546.96
# 1455  1000.36  537.24
# 1456  1000.38  529.34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1457 entries, 0 to 1456
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       1457 non-null   float64
#  1   Y       1457 non-null   float64
# dtypes: float64(2)
# memory usage: 22.9 KB

# %%
df['X'] = df['X'].round(2)
df['Y'] = df['Y'].round(2)

# %%
pd.Series(df['X'].unique())
# Out:
# 0          3.58
# 1          4.57
# 2          4.98
# 3          5.07
# 4          6.19
#          ...
# 1445     999.94
# 1446    1000.59
# 1447    1000.24
# 1448    1000.36
# 1449    1000.38
# Length: 1450, dtype: float64

# %%
df['X'].value_counts()
df['Y'].value_counts()
# Out:
# Y
# 219.54    2
# 884.72    2
# 837.00    2
# 957.58    2
# 349.23    2
#          ..
# 236.90    1
# 246.62    1
# 166.42    1
# 197.89    1
# 529.34    1
# Name: count, Length: 1448, dtype: int64

# %%
df= df.drop_duplicates(subset='X', keep='first')

# %%
df= df.drop_duplicates(subset='Y', keep='first')

# %%
# Cleaned dataframe
df
# Out:
#             X       Y
# 0        3.58  457.94
# 1        4.57  488.84
# 2        4.98  445.82
# 3        5.07  504.32
# 4        6.19  432.79
# ...       ...     ...
# 1451   999.94  493.89
# 1452  1000.59  516.13
# 1454  1000.24  546.96
# 1455  1000.36  537.24
# 1456  1000.38  529.34
#
# [1441 rows x 2 columns]

# %%
from scipy.sparse import csr_matrix
sparse_matrix = csr_matrix(df)
print(sparse_matrix)
sparse_matrix.ndim
print(sparse_matrix.dtype)
print(type(sparse_matrix))
# Out:
#   (0, 0)	3.58
#   (0, 1)	457.94
#   (1, 0)	4.57
#   (1, 1)	488.84
#   (2, 0)	4.98
#   (2, 1)	445.82
#   (3, 0)	5.07
#   (3, 1)	504.32
#   (4, 0)	6.19
#   (4, 1)	432.79
#   (5, 0)	5.68
#   (5, 1)	423.66
#   (6, 0)	6.06
#   (6, 1)	515.87
#   (7, 0)	7.35
#   (7, 1)	414.66
#   (8, 0)	8.31
#   (8, 1)	405.29
#   (9, 0)	7.47
#   (9, 1)	528.27
#   (10, 0)	10.34
#   (10, 1)	395.16
#   (11, 0)	9.33
#   (11, 1)	541.2
#   (12, 0)	11.07
#   :	:
#   (1428, 1)	605.81
#   (1429, 0)	995.87
#   (1429, 1)	456.49
#   (1430, 0)	997.92
#   (1430, 1)	468.63
#   (1431, 0)	996.4
#   (1431, 1)	594.28
#   (1432, 0)	996.85
#   (1432, 1)	582.99
#   (1433, 0)	998.48
#   (1433, 1)	570.97
#   (1434, 0)	998.58
#   (1434, 1)	480.33
#   (1435, 0)	999.19
#   (1435, 1)	557.98
#   (1436, 0)	999.94
#   (1436, 1)	493.89
#   (1437, 0)	1000.59
#   (1437, 1)	516.13
#   (1438, 0)	1000.24
#   (1438, 1)	546.96
#   (1439, 0)	1000.36
#   (1439, 1)	537.24
#   (1440, 0)	1000.38
#   (1440, 1)	529.34
# float64
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
arr= sparse_matrix.toarray()
print(arr)
print(arr.ndim)
print(arr.shape)
print(type(arr))
# Out:
# [[   3.58  457.94]
#  [   4.57  488.84]
#  [   4.98  445.82]
#  ...
#  [1000.24  546.96]
#  [1000.36  537.24]
#  [1000.38  529.34]]
# 2
# (1441, 2)
# <class 'numpy.ndarray'>

# %%
arr = sparse_matrix.toarray()
print(arr)
print(arr.ndim)
print(arr.shape)
print(type(arr))
import numpy as np
from scipy.sparse import csr_matrix

mat_s = 1000

min_x = np.min(n_m[:, 0])
min_y = np.min(n_m[:, 1])
max_x = np.max(n_m[:, 0])
max_y = np.max(n_m[:, 1])

# we defined min and max as it is need in discretization.

#IMPORTANT as formula i.e[ normalization * (n-1)]
discretized_x = np.clip(((n_m[:, 0] - min_x) / (max_x - min_x) * (mat_s - 1)).astype(int), 0, mat_s - 1)
discretized_y = np.clip(((n_m[:, 1] - min_y) / (max_y - min_y) * (mat_s - 1)).astype(int), 0, mat_s - 1)

print(discretized_x.ndim)  
print(discretized_x.size)  

bool_m = np.zeros((mat_s, mat_s), dtype=bool)  # boolean given.

for x, y in zip(discretized_x, discretized_y): #zip is used to write two tuple,list,vector ect together.
    bool_m[x, y] = True   
        
sparse_matrix1 = csr_matrix(bool_m)
print(sparse_matrix1)
print(sparse_matrix1.ndim)
print(type(sparse_matrix1))
# Out:
# [[   3.58  457.94]
#  [   4.57  488.84]
#  [   4.98  445.82]
#  ...
#  [1000.24  546.96]
#  [1000.36  537.24]
#  [1000.38  529.34]]
# 2
# (1441, 2)
# <class 'numpy.ndarray'>
# 1
# 1441
#   (0, 458)	True
#   (0, 489)	True
#   (1, 446)	True
#   (1, 505)	True
#   (2, 424)	True
#   (2, 433)	True
#   (2, 516)	True
#   (3, 415)	True
#   (3, 529)	True
#   (4, 405)	True
#   (5, 541)	True
#   (6, 395)	True
#   (7, 386)	True
#   (7, 483)	True
#   (7, 553)	True
#   (8, 458)	True
#   (8, 472)	True
#   (8, 562)	True
#   (9, 375)	True
#   (9, 445)	True
#   (9, 494)	True
#   (10, 428)	True
#   (10, 513)	True
#   (11, 366)	True
#   (11, 572)	True
#   :	:
#   (988, 478)	True
#   (988, 563)	True
#   (989, 497)	True
#   (989, 627)	True
#   (990, 432)	True
#   (990, 485)	True
#   (990, 512)	True
#   (990, 523)	True
#   (990, 536)	True
#   (990, 550)	True
#   (990, 616)	True
#   (992, 444)	True
#   (992, 606)	True
#   (994, 457)	True
#   (994, 595)	True
#   (995, 583)	True
#   (996, 469)	True
#   (996, 480)	True
#   (996, 571)	True
#   (997, 558)	True
#   (998, 494)	True
#   (998, 530)	True
#   (998, 538)	True
#   (998, 547)	True
#   (999, 516)	True
# 2
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
numpy_1 = sparse_matrix1.toarray()
print(numpy_1)
print(numpy_1.ndim)
print(numpy_1.size)
# Out:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# 2
# 1000000

# %%
# Rotate by 90 degree
rotate_df1 = np.rot90(numpy_1, k=-1)
rotate_df1
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
# FLip 
rotate_df2 = np.rot90(numpy_1, k=-2)
rotate_df2
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
# 2nd Image

import matplotlib.pyplot as plt
import numpy as np

rows, cols = np.nonzero(rotate_df1)

# Create a subplot and scatter plot
plt.figure(figsize=(8, 8))
ax1 = plt.subplot()
ax1.scatter(rows, cols , s=40)
plt.grid(True)

# Display the plot
plt.show()

# %%
# 3rd Image

import matplotlib.pyplot as plt
import numpy as np

rows, cols = np.nonzero(rotate_df2)

# Create a subplot and scatter plot
plt.figure(figsize=(8, 8))
ax1 = plt.subplot()
ax1.scatter(rows, cols , s=40)
plt.grid(True)

# Display the plot
plt.show()
